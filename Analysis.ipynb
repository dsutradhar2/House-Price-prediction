# %%
import pandas as pd
import seaborn as sns

# %%
housing_train = pd.read_csv('train.csv')
housing_test = pd.read_csv('test.csv')
Y_label =  housing_train['SalePrice'].copy()
all_data = pd.concat([housing_train, housing_test])

# %%
all_data["GarageYrBlt"].fillna(0, inplace=True)
all_data["MasVnrArea"].fillna(0, inplace=True)
all_data["LotFrontage"].fillna(0, inplace=True)
all_data["Alley"].fillna('None', inplace=True)
all_data["MasVnrType"].fillna('None', inplace=True)
all_data["BsmtQual"].fillna('None', inplace=True)
all_data["BsmtCond"].fillna('None', inplace=True)
all_data["BsmtExposure"].fillna('None', inplace=True)
all_data["BsmtFinType1"].fillna('None', inplace=True)
all_data["BsmtFinType2"].fillna('None', inplace=True)
all_data["Electrical"].fillna(housing_train["Electrical"].mode()[0], inplace=True)
all_data["FireplaceQu"].fillna('None', inplace=True)
all_data["GarageType"].fillna('None', inplace=True)
all_data["GarageFinish"].fillna('None', inplace=True)
all_data["GarageQual"].fillna('None', inplace=True)
all_data["GarageCond"].fillna('None', inplace=True)
all_data["PoolQC"].fillna('None', inplace=True)
all_data["Fence"].fillna('None', inplace=True)
all_data["MiscFeature"].fillna('None', inplace=True)
all_data["MSZoning"].fillna(housing_test["MSZoning"].mode()[0], inplace=True)
all_data["Exterior1st"].fillna(housing_test["Exterior1st"].mode()[0], inplace=True)
all_data["Exterior2nd"].fillna(housing_test["Exterior2nd"].mode()[0], inplace=True)
all_data["BsmtUnfSF"].fillna(housing_test["BsmtUnfSF"].mean(), inplace=True)
all_data["TotalBsmtSF"].fillna(housing_test["TotalBsmtSF"].mean(), inplace=True)
all_data["BsmtFinSF1"].fillna(housing_test["BsmtFinSF1"].mean(), inplace=True)
all_data["BsmtFullBath"].fillna(housing_test["BsmtFullBath"].mode()[0], inplace=True)
all_data["KitchenQual"].fillna(housing_test["KitchenQual"].mode()[0], inplace=True)
all_data["GarageArea"].fillna(0, inplace=True)
all_data["GarageCars"].fillna(0, inplace=True)
all_data["Functional"].fillna(housing_test["Functional"].mode()[0], inplace=True)
all_data["SaleType"].fillna(housing_test["SaleType"].mode()[0], inplace=True)

# %% [markdown]
# # Shows corelation of features with label

# %%
corr_matrix= housing_train.corr()
corr_matrix['SalePrice'].sort_values(ascending=False)
# Out:
# /tmp/ipykernel_5612/1578365848.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix= housing_train.corr()
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# ...

# %% [markdown]
# # Bar plot of some categorical features

# %%
print(all_data['Utilities'].value_counts()) #dropped
sns.barplot(x='Utilities',y='SalePrice',data=all_data)
# Out:
# AllPub    2916
# NoSeWa       1
# Name: Utilities, dtype: int64
# <AxesSubplot: xlabel='Utilities', ylabel='SalePrice'>

# %%
all_data['LandSlope'].value_counts()
sns.barplot(x='LandSlope',y='SalePrice',data=all_data)
# Out:
# <AxesSubplot: xlabel='LandSlope', ylabel='SalePrice'>

# %%
all_data['ExterQual'].value_counts()
sns.barplot(x='ExterQual',y='SalePrice',data=all_data)
# Out:
# <AxesSubplot: xlabel='ExterQual', ylabel='SalePrice'>

# %%
print(all_data['ExterCond'].value_counts())
sns.barplot(x='ExterCond',y='SalePrice',data=all_data)
# Out:
# TA    2538
# Gd     299
# Fa      67
# Ex      12
# Po       3
# Name: ExterCond, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='ExterCond', ylabel='SalePrice'>

# %%
print(all_data['BsmtQual'].value_counts())
sns.barplot(x='BsmtQual',y='SalePrice',data=all_data)
# Out:
# TA      1283
# Gd      1209
# Ex       258
# Fa        88
# None      81
# Name: BsmtQual, dtype: int64
# <AxesSubplot: xlabel='BsmtQual', ylabel='SalePrice'>

# %%
print(all_data['BsmtCond'].value_counts())
sns.barplot(x='BsmtCond',y='SalePrice',data=all_data)
# Out:
# TA      2606
# Gd       122
# Fa       104
# None      82
# Po         5
# Name: BsmtCond, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='BsmtCond', ylabel='SalePrice'>

# %%
print(all_data['BsmtExposure'].value_counts())
sns.barplot(x='BsmtExposure',y='SalePrice',data=all_data)
# Out:
# No      1904
# Av       418
# Gd       276
# Mn       239
# None      82
# Name: BsmtExposure, dtype: int64
# <AxesSubplot: xlabel='BsmtExposure', ylabel='SalePrice'>

# %%
print(all_data['BsmtFinType1'].value_counts())
sns.barplot(x='BsmtFinType1',y='SalePrice',data=all_data)
# Out:
# Unf     851
# GLQ     849
# ALQ     429
# Rec     288
# BLQ     269
# LwQ     154
# None     79
# Name: BsmtFinType1, dtype: int64
# <AxesSubplot: xlabel='BsmtFinType1', ylabel='SalePrice'>

# %%
print(all_data['BsmtFinType2'].value_counts())
sns.barplot(x='BsmtFinType2',y='SalePrice',data=all_data)
# Out:
# Unf     2493
# Rec      105
# LwQ       87
# None      80
# BLQ       68
# ALQ       52
# GLQ       34
# Name: BsmtFinType2, dtype: int64
# <AxesSubplot: xlabel='BsmtFinType2', ylabel='SalePrice'>

# %%
print(all_data['HeatingQC'].value_counts())
sns.barplot(x='HeatingQC',y='SalePrice',data=all_data)
# Out:
# Ex    1493
# TA     857
# Gd     474
# Fa      92
# Po       3
# Name: HeatingQC, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='HeatingQC', ylabel='SalePrice'>

# %%
print(all_data['CentralAir'].value_counts())
sns.barplot(x='CentralAir',y='SalePrice',data=all_data)
# Out:
# Y    2723
# N     196
# Name: CentralAir, dtype: int64
# <AxesSubplot: xlabel='CentralAir', ylabel='SalePrice'>

# %%
print(all_data['KitchenQual'].value_counts())
sns.barplot(x='KitchenQual',y='SalePrice',data=all_data)
# Out:
# TA    1493
# Gd    1151
# Ex     205
# Fa      70
# Name: KitchenQual, dtype: int64
# <AxesSubplot: xlabel='KitchenQual', ylabel='SalePrice'>

# %%
print(all_data['Functional'].value_counts())
sns.barplot(x='Functional',y='SalePrice',data=all_data)
# Out:
# Typ     2719
# Min2      70
# Min1      65
# Mod       35
# Maj1      19
# Maj2       9
# Sev        2
# Name: Functional, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='Functional', ylabel='SalePrice'>

# %%
print(all_data['FireplaceQu'].value_counts())
sns.barplot(x='FireplaceQu',y='SalePrice',data=all_data)
# Out:
# None    1420
# Gd       744
# TA       592
# Fa        74
# Po        46
# Ex        43
# Name: FireplaceQu, dtype: int64
# <AxesSubplot: xlabel='FireplaceQu', ylabel='SalePrice'>

# %%
print(all_data['GarageType'].value_counts())
sns.barplot(x='GarageType',y='SalePrice',data=all_data)
# Out:
# Attchd     1723
# Detchd      779
# BuiltIn     186
# None        157
# Basment      36
# 2Types       23
# CarPort      15
# Name: GarageType, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='GarageType', ylabel='SalePrice'>

# %%
print(all_data['GarageFinish'].value_counts())
sns.barplot(x='GarageFinish',y='SalePrice',data=all_data)
# Out:
# Unf     1230
# RFn      811
# Fin      719
# None     159
# Name: GarageFinish, dtype: int64
# <AxesSubplot: xlabel='GarageFinish', ylabel='SalePrice'>

# %%
print(all_data['GarageQual'].value_counts())
sns.barplot(x='GarageQual',y='SalePrice',data=all_data)
# Out:
# TA      2604
# None     159
# Fa       124
# Gd        24
# Po         5
# Ex         3
# Name: GarageQual, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='GarageQual', ylabel='SalePrice'>

# %%
print(all_data['GarageCond'].value_counts())
sns.barplot(x='GarageCond',y='SalePrice',data=all_data)
# Out:
# TA      2654
# None     159
# Fa        74
# Gd        15
# Po        14
# Ex         3
# Name: GarageCond, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='GarageCond', ylabel='SalePrice'>

# %%
print(all_data['PavedDrive'].value_counts())
sns.barplot(x='PavedDrive',y='SalePrice',data=all_data)
# Out:
# Y    2641
# N     216
# P      62
# Name: PavedDrive, dtype: int64
# <AxesSubplot: xlabel='PavedDrive', ylabel='SalePrice'>

# %%
print(all_data['PoolQC'].value_counts())
sns.barplot(x='PoolQC',y='SalePrice',data=all_data)
# Out:
# None    2909
# Ex         4
# Gd         4
# Fa         2
# Name: PoolQC, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='PoolQC', ylabel='SalePrice'>

# %%
print(all_data['Fence'].value_counts())
sns.barplot(x='Fence',y='SalePrice',data=all_data)
# Out:
# None     2348
# MnPrv     329
# GdPrv     118
# GdWo      112
# MnWw       12
# Name: Fence, dtype: int64
# <AxesSubplot: xlabel='Fence', ylabel='SalePrice'>

# %%
print(all_data['MSZoning'].value_counts())
sns.barplot(x='MSZoning',y='SalePrice',data=all_data)
# Out:
# RL         2269
# RM          460
# FV          139
# RH           26
# C (all)      25
# Name: MSZoning, dtype: int64
# <AxesSubplot: xlabel='MSZoning', ylabel='SalePrice'>

# %%
print(all_data['Street'].value_counts())
sns.barplot(x='Street',y='SalePrice',data=all_data)
# Out:
# Pave    2907
# Grvl      12
# Name: Street, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='Street', ylabel='SalePrice'>

# %%
print(all_data['Alley'].value_counts())
sns.barplot(x='Alley',y='SalePrice',data=all_data)
# Out:
# None    2721
# Grvl     120
# Pave      78
# Name: Alley, dtype: int64
# <AxesSubplot: xlabel='Alley', ylabel='SalePrice'>

# %%
print(all_data['LotShape'].value_counts())
sns.barplot(x='LotShape',y='SalePrice',data=all_data)
# Out:
# Reg    1859
# IR1     968
# IR2      76
# IR3      16
# Name: LotShape, dtype: int64
# <AxesSubplot: xlabel='LotShape', ylabel='SalePrice'>

# %%
print(all_data['LandContour'].value_counts())
sns.barplot(x='LandContour',y='SalePrice',data=all_data)
# Out:
# Lvl    2622
# HLS     120
# Bnk     117
# Low      60
# Name: LandContour, dtype: int64
# <AxesSubplot: xlabel='LandContour', ylabel='SalePrice'>

# %%
print(all_data['LotConfig'].value_counts())
sns.barplot(x='LotConfig',y='SalePrice',data=all_data)
# Out:
# Inside     2133
# Corner      511
# CulDSac     176
# FR2          85
# FR3          14
# Name: LotConfig, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='LotConfig', ylabel='SalePrice'>

# %%
print(all_data['Neighborhood'].value_counts())
sns.barplot(x='Neighborhood',y='SalePrice',data=all_data)
# Out:
# NAmes      443
# CollgCr    267
# OldTown    239
# Edwards    194
# Somerst    182
# NridgHt    166
# Gilbert    165
# Sawyer     151
# NWAmes     131
# SawyerW    125
# Mitchel    114
# BrkSide    108
# Crawfor    103
# IDOTRR      93
# Timber      72
# NoRidge     71
# StoneBr     51
# SWISU       48
# ClearCr     44
# MeadowV     37
# BrDale      30
# Blmngtn     28
# Veenker     24
# NPkVill     23
# Blueste     10
# Name: Neighborhood, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='Neighborhood', ylabel='SalePrice'>

# %%
print(all_data['Condition1'].value_counts())
sns.barplot(x='Condition1',y='SalePrice',data=all_data)
# Out:
# Norm      2511
# Feedr      164
# Artery      92
# RRAn        50
# PosN        39
# RRAe        28
# PosA        20
# RRNn         9
# RRNe         6
# Name: Condition1, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='Condition1', ylabel='SalePrice'>

# %%
print(all_data['Condition2'].value_counts())
sns.barplot(x='Condition2',y='SalePrice',data=all_data)
# Out:
# Norm      2889
# Feedr       13
# Artery       5
# PosN         4
# PosA         4
# RRNn         2
# RRAn         1
# RRAe         1
# Name: Condition2, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='Condition2', ylabel='SalePrice'>

# %%
print(all_data['BldgType'].value_counts())
sns.barplot(x='BldgType',y='SalePrice',data=all_data)
# Out:
# 1Fam      2425
# TwnhsE     227
# Duplex     109
# Twnhs       96
# 2fmCon      62
# Name: BldgType, dtype: int64
# <AxesSubplot: xlabel='BldgType', ylabel='SalePrice'>

# %%
print(all_data['HouseStyle'].value_counts())
sns.barplot(x='HouseStyle',y='SalePrice',data=all_data)
# Out:
# 1Story    1471
# 2Story     872
# 1.5Fin     314
# SLvl       128
# SFoyer      83
# 2.5Unf      24
# 1.5Unf      19
# 2.5Fin       8
# Name: HouseStyle, dtype: int64
# <AxesSubplot: xlabel='HouseStyle', ylabel='SalePrice'>

# %%
print(all_data['GarageCond'].value_counts())
sns.barplot(x='GarageCond',y='SalePrice',data=all_data)
# Out:
# TA      2654
# None     159
# Fa        74
# Gd        15
# Po        14
# Ex         3
# Name: GarageCond, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='GarageCond', ylabel='SalePrice'>

# %%
print(all_data['RoofStyle'].value_counts())
sns.barplot(x='RoofStyle',y='SalePrice',data=all_data)
# Out:
# Gable      2310
# Hip         551
# Gambrel      22
# Flat         20
# Mansard      11
# Shed          5
# Name: RoofStyle, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='RoofStyle', ylabel='SalePrice'>

# %%
print(all_data['RoofMatl'].value_counts())
sns.barplot(x='RoofMatl',y='SalePrice',data=all_data)
# Out:
# CompShg    2876
# Tar&Grv      23
# WdShake       9
# WdShngl       7
# Metal         1
# Membran       1
# Roll          1
# ClyTile       1
# Name: RoofMatl, dtype: int64
# <AxesSubplot: xlabel='RoofMatl', ylabel='SalePrice'>

# %%
print(all_data['Exterior1st'].value_counts())
sns.barplot(x='Exterior1st',y='SalePrice',data=all_data)
# Out:
# VinylSd    1026
# MetalSd     450
# HdBoard     442
# Wd Sdng     411
# Plywood     221
# CemntBd     126
# BrkFace      87
# WdShing      56
# AsbShng      44
# Stucco       43
# BrkComm       6
# AsphShn       2
# Stone         2
# CBlock        2
# ImStucc       1
# Name: Exterior1st, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='Exterior1st', ylabel='SalePrice'>

# %%
print(all_data['Exterior2nd'].value_counts())
sns.barplot(x='Exterior2nd',y='SalePrice',data=all_data)
# Out:
# VinylSd    1015
# MetalSd     447
# HdBoard     406
# Wd Sdng     391
# Plywood     270
# CmentBd     126
# Wd Shng      81
# BrkFace      47
# Stucco       47
# AsbShng      38
# Brk Cmn      22
# ImStucc      15
# Stone         6
# AsphShn       4
# CBlock        3
# Other         1
# Name: Exterior2nd, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='Exterior2nd', ylabel='SalePrice'>

# %%
print(all_data['MasVnrType'].value_counts())
sns.barplot(x='MasVnrType',y='SalePrice',data=all_data)
# Out:
# None       1766
# BrkFace     879
# Stone       249
# BrkCmn       25
# Name: MasVnrType, dtype: int64
# <AxesSubplot: xlabel='MasVnrType', ylabel='SalePrice'>

# %%
print(all_data['Foundation'].value_counts())
sns.barplot(x='Foundation',y='SalePrice',data=all_data)
# Out:
# PConc     1308
# CBlock    1235
# BrkTil     311
# Slab        49
# Stone       11
# Wood         5
# Name: Foundation, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='Foundation', ylabel='SalePrice'>

# %%
print(all_data['Heating'].value_counts())
sns.barplot(x='Heating',y='SalePrice',data=all_data)
# Out:
# GasA     2874
# GasW       27
# Grav        9
# Wall        6
# OthW        2
# Floor       1
# Name: Heating, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='Heating', ylabel='SalePrice'>

# %%
print(all_data['Electrical'].value_counts())
sns.barplot(x='Electrical',y='SalePrice',data=all_data)
# Out:
# SBrkr    2672
# FuseA     188
# FuseF      50
# FuseP       8
# Mix         1
# Name: Electrical, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='Electrical', ylabel='SalePrice'>

# %%
print(all_data['MiscFeature'].value_counts())
sns.barplot(x='MiscFeature',y='SalePrice',data=all_data)
# Out:
# None    2814
# Shed      95
# Gar2       5
# Othr       4
# TenC       1
# Name: MiscFeature, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='MiscFeature', ylabel='SalePrice'>

# %%
print(all_data['SaleType'].value_counts())
sns.barplot(x='SaleType',y='SalePrice',data=all_data)
# Out:
# WD       2526
# New       239
# COD        87
# ConLD      26
# CWD        12
# ConLI       9
# ConLw       8
# Oth         7
# Con         5
# Name: SaleType, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='SaleType', ylabel='SalePrice'>

# %%
print(all_data['SaleCondition'].value_counts())
sns.barplot(x='SaleCondition',y='SalePrice',data=all_data)
# Out:
# Normal     2402
# Partial     245
# Abnorml     190
# Family       46
# Alloca       24
# AdjLand      12
# Name: SaleCondition, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='SaleCondition', ylabel='SalePrice'>

# %%
print(all_data['GarageYrBlt'].value_counts())
sns.barplot(x='GarageYrBlt',y='SalePrice',data=all_data)
# Out:
# 0.0       159
# 2005.0    142
# 2007.0    115
# 2006.0    115
# 2004.0     99
#          ...
# 1908.0      1
# 1896.0      1
# 1933.0      1
# 1906.0      1
# 1919.0      1
# Name: GarageYrBlt, Length: 104, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /home/deb/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1559: RuntimeWarning: All-NaN slice encountered
# ...

# %%
print(all_data['OverallCond'].value_counts())
sns.barplot(x='OverallCond',y='SalePrice',data=all_data)
# Out:
# 5    1645
# 6     531
# 7     390
# 8     144
# 4     101
# 3      50
# 9      41
# 2      10
# 1       7
# Name: OverallCond, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='OverallCond', ylabel='SalePrice'>

# %%
print(all_data['KitchenAbvGr'].value_counts())
sns.barplot(x='KitchenAbvGr',y='SalePrice',data=all_data)
# Out:
# 1    2785
# 2     129
# 0       3
# 3       2
# Name: KitchenAbvGr, dtype: int64
# /home/deb/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <AxesSubplot: xlabel='KitchenAbvGr', ylabel='SalePrice'>
